# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkurGuptaGithub/Signboard-Translation/blob/main/st_Custom_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clone YOLOv5 and reset to a specific git checkpoint that has been verified working
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard 68211f72c99915a15855f7b99bf5d93f5631330f
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 4979 (delta 24), reused 25 (delta 12), pack-reused 4935
# Receiving objects: 100% (4979/4979), 7.91 MiB | 12.73 MiB/s, done.
# Resolving deltas: 100% (3384/3384), done.
# /content/yolov5
# HEAD is now at 68211f7 FROM nvcr.io/nvidia/pytorch:20.10-py3 (#1553)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      |████████████████████████████████| 645kB 8.4MB/s
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# Export code snippet and paste here
# %cd /content
# !curl -L "https://app.roboflow.com/ds/eCbLV7ct6v?key=y9R9y6278D" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/labels/2_1283_jpg.rf.6bcf2bf7a9d3b79c6163a1ddee2a74a2.txt
#  extracting: train/labels/2_1284_jpg.rf.fbe260e74e8a542a44f8053ea8b7028d.txt
#  extracting: train/labels/2_1285_jpg.rf.72651e816c78306ff00fded288254f8e.txt
#  extracting: train/labels/2_1286_jpg.rf.3ed5fe60fa8068ced709ffabffd41a19.txt
#  extracting: train/labels/2_1288_jpg.rf.263f3b5f63d7b2389e38b03c19c7a96b.txt
#  extracting: train/labels/2_128_jpg.rf.57b7ae35bb41bf83106fb0abcb1b5b0a.txt
#  extracting: train/labels/2_1291_jpg.rf.b0aa12a88f8c2b355a29e574b960188f.txt
#  extracting: train/labels/2_1292_jpg.rf.b5cba6f5a5a7b10d75d6d3dad06164a7.txt
#  extracting: train/labels/2_1293_jpg.rf.a8042391dfbf24ee3a29c4cd8074d127.txt
#  extracting: train/labels/2_1296_jpg.rf.f4df413a825fbbbaada0c2f1dede1729.txt
#  extracting: train/labels/2_1297_jpg.rf.b49d71a92bedf51b81f20d0327505b17.txt
#  extracting: train/labels/2_1298_jpg.rf.e9aa3dadecf2260a433ac64aa364b4ee.txt
#  extracting: train/labels/2_1299_jpg.rf.0724dd571178aeea5013dd5ca7efbe76.txt
#  extracting: train/labels/2_129_jpg.rf.e60e51ce58cd583c5955baadb9aec59a.txt
#  extracting: train/labels/2_12_jpg.rf.bc4f3e2be792bdc285c706c11e23a66c.txt
#  extracting: train/labels/2_1300_jpg.rf.31ff1f1cf97c337d5581282ed07c34d3.txt
#  extracting: train/labels/2_1301_jpg.rf.0a2c6a695ba74ace1e98408307d3b73a.txt
#  extracting: train/labels/2_1302_jpg.rf.991e7d93253b0522fa8e584117bf31da.txt
#  extracting: train/labels/2_1303_jpg.rf.90e88a3409528d4f1537c7df8b11059e.txt
#  extracting: train/labels/2_1304_jpg.rf.2decfde823c33ad7bedf3b2e90ae47b3.txt
#  extracting: train/labels/2_1305_jpg.rf.1f20a5a13dcf73f1c3f2fec468fdf7a4.txt
#  extracting: train/labels/2_1306_jpg.rf.0d64cdbfbc5453e6ce8376328b6c6227.txt
#  extracting: train/labels/2_1307_jpg.rf.63f216a8174272e695694f5f5f237360.txt
#  extracting: train/labels/2_1308_jpg.rf.aee73ed7ada0947eef1a280bfc58505e.txt
#  extracting: train/labels/2_1309_jpg.rf.0da6821f13d1813dac76645787d6e70d.txt
#  extracting: train/labels/2_130_jpg.rf.301180a9aa7076bac7c87aed2e56bf0e.txt
#  extracting: train/labels/2_1310_jpg.rf.d2145d240b307ce09718a83c18451ac8.txt
#  extracting: train/labels/2_1312_jpg.rf.84ae2fcf7350a7b77d7ca433edfe440b.txt
#  extracting: train/labels/2_1313_jpg.rf.e80decc65250cb01c638ac7d9179925c.txt
#  extracting: train/labels/2_1315_jpg.rf.4225bc5738382abe1ad360d1cb8d4855.txt
#  extracting: train/labels/2_1316_jpg.rf.14e1898692fdbbb9e9e8b5ec3b2344df.txt
#  extracting: train/labels/2_1318_jpg.rf.8ff0120e888cdbd261ad03bdec24082c.txt
#  extracting: train/labels/2_1320_jpg.rf.fe9869211441b13825d6d795d2794e97.txt
#  extracting: train/labels/2_1321_jpg.rf.55e66dbb828603eed3ff590438c51602.txt
#  extracting: train/labels/2_1322_jpg.rf.2e92b483d1d0ad2caed634ee8b1e3454.txt
#  extracting: train/labels/2_1323_jpg.rf.3bf72a62c4ba341b13e0cfecbb24533f.txt
#  extracting: train/labels/2_1324_jpg.rf.c218b71e855ed0422dcc04588d4a35f5.txt
#  extracting: train/labels/2_1327_jpg.rf.b591c4d5ccf32d3d24b2200e1c92b876.txt
#  extracting: train/labels/2_1328_jpg.rf.cc2e43266e72b2a88f39fa79e16cc24e.txt
#  extracting: train/labels/2_1329_jpg.rf.81c921af5eeb2e7b3c21162ead1833ed.txt
#  extracting: train/labels/2_132_jpg.rf.5ef148d31c77291672bc3d75ff165027.txt
#  extracting: train/labels/2_1330_jpg.rf.876b7f1eb500d1c44a2c461ce0ae01f7.txt
#  extracting: train/labels/2_1331_jpg.rf.7088a968fa39694e5b6052a3c85d31af.txt
#  extracting: train/labels/2_1332_jpg.rf.bdb2b304174e532716b04f63688bfb40.txt
#  extracting: train/labels/2_1333_jpg.rf.0b7f1f65d151576f81dd2525f615a26f.txt
#  extracting: train/labels/2_1334_jpg.rf.8d5866358db00e74ab3dc7c3cc224a94.txt
#  extracting: train/labels/2_1336_jpg.rf.3ecc7ad3f11ec35b0491787a8637effb.txt
#  extracting: train/labels/2_1338_jpg.rf.7c97f3885a35cf9be82c17520fb011cb.txt
#  extracting: train/labels/2_133_jpg.rf.cf0de4e39cf90140128af8007046197e.txt
#  extracting: train/labels/2_1340_jpg.rf.8820aca5bc1a58b80f9dd155ceb0c995.txt
#  extracting: train/labels/2_1343_jpg.rf.809f0d04af22a1d1963c34c3981c1f1e.txt
#  extracting: train/labels/2_1506_jpg.rf.58cfab9a7276de4ede8e963addc00905.txt
#  extracting: train/labels/2_1507_jpg.rf.8e75deb85c8b125d078f77eb8dcc375d.txt
#  extracting: train/labels/2_1508_jpg.rf.14953bd4a6d01d4a78534a1b63cb9d1e.txt
#  extracting: train/labels/2_150_jpg.rf.4f81d65e8398ade3e4db83632c3f59c1.txt
#  extracting: train/labels/2_1510_jpg.rf.e96ccced926cc30e6ab3e70f38d90015.txt
#  extracting: train/labels/2_1511_jpg.rf.ec0aeb03134153c7480c39cac57ca4d3.txt
#  extracting: train/labels/2_1512_jpg.rf.f7f3eb78502b0b5ca81ebd62ecbe1928.txt
#  extracting: train/labels/2_1513_jpg.rf.fecd7ded8ec0ebfb3578fbc2b4c123a6.txt
#  extracting: train/labels/2_1515_jpg.rf.fdf8aa3974ad538bfd933c794076081d.txt
#  extracting: train/labels/2_1516_jpg.rf.cde7b17f128e08f966d98a6a694693aa.txt
#  extracting: train/labels/2_1518_jpg.rf.8646047785ccf12ec31ac3d585a3b255.txt
#  extracting: train/labels/2_151_jpg.rf.3b82f7a74bb819021e98cc458c3f463e.txt
#  extracting: train/labels/2_1520_jpg.rf.2d2bdc1e24f16a0b0dcbaccc2cbf4ace.txt
#  extracting: train/labels/2_1521_jpg.rf.e658b166be5def604f6ae78087861684.txt
#  extracting: train/labels/2_1525_jpg.rf.93361f9d640db017fa9cf1b4c2f636e5.txt
#  extracting: train/labels/2_1526_jpg.rf.85aa4e8b86acf5cf3d579470dab6754e.txt
#  extracting: train/labels/2_1527_jpg.rf.7f1071eae77ca2bbd5da0c9fea39074c.txt
#  extracting: train/labels/2_1528_jpg.rf.576b5ebd47d27eeefd15bd7295afac4d.txt
#  extracting: train/labels/2_1529_jpg.rf.28d235fb745331d6709aeef42439664e.txt
#  extracting: train/labels/2_152_jpg.rf.a01f9fea61147d8bede72529671e9194.txt
#  extracting: train/labels/2_1530_jpg.rf.fa9e7c573fd47793dac20830125818d4.txt
#  extracting: train/labels/2_1531_jpg.rf.8891c6c65869766db867e5ee38382d88.txt
#  extracting: train/labels/2_1534_jpg.rf.e9812a62800b51dbe7751b91dea81534.txt
#  extracting: train/labels/2_1536_jpg.rf.9e55591ef4f61c4e7025bc80c30e759a.txt
#  extracting: train/labels/2_1537_jpg.rf.04cbef2e502cdcb4ee44b53cb079e33e.txt
#  extracting: train/labels/2_153_jpg.rf.df2a461134a7a159395959ad3b205a14.txt
#  extracting: train/labels/2_1540_jpg.rf.a81e2d1115ef10bd90aa653ac8168087.txt
#  extracting: train/labels/2_1541_jpg.rf.49786f9b541723b5daf5a1c12cb1620a.txt
#  extracting: train/labels/2_1542_jpg.rf.ad26d9542e876de3f18a0224145e862c.txt
#  extracting: train/labels/2_1543_jpg.rf.121f506e0b4690a746e0bd83be1f978f.txt
#  extracting: train/labels/2_1545_jpg.rf.12bff38fc49d3f035b1a294161113f10.txt
#  extracting: train/labels/2_1546_jpg.rf.6567df97245812da0649146c048d3c8f.txt
#  extracting: train/labels/2_1583_jpg.rf.367eb4560ba2672891039be1843d3bdf.txt
#  extracting: train/labels/2_1586_jpg.rf.f58c47eec9318f598d7bdb1d1e9d3ce5.txt
#  extracting: train/labels/2_1588_jpg.rf.10a22e9b06d4509caf5e5bb04999cad0.txt
#  extracting: train/labels/2_1590_jpg.rf.7f2888a4e4bb1b59ea428d852b8b31a8.txt
#  extracting: train/labels/2_1592_jpg.rf.bdcf121fa40f62000911fdf2aafab190.txt
#  extracting: train/labels/2_1593_jpg.rf.44b4b13570d966436105c7d663f1b8f0.txt
#  extracting: train/labels/2_1594_jpg.rf.6768a63b57b910dbc77c45093c9806c1.txt
#  extracting: train/labels/2_1595_jpg.rf.4b65c38b981ae1eaa676ffcfb8cef1a3.txt
#  extracting: train/labels/2_1596_jpg.rf.66ff3c714c9555ce38ba3d0d45788e70.txt
#  extracting: train/labels/2_1598_jpg.rf.bedf4a108f66d7f8224ac5cb15f8d87b.txt
#  extracting: train/labels/2_1599_jpg.rf.cb7638ad009bbe0679714521f330e212.txt
#  extracting: train/labels/2_159_jpg.rf.13dd8d183cfd8e18dfa70b27e598f8e2.txt
#  extracting: train/labels/2_15_jpg.rf.ec13f505bbf415306f0c2fddd697266c.txt
#  extracting: train/labels/2_1600_jpg.rf.776e54847e26f5f142bcf5f36acb0d55.txt
#  extracting: train/labels/2_1601_jpg.rf.bd9e714b2760f31493dce5465c49c3b8.txt
#  extracting: train/labels/2_1604_jpg.rf.79d3c1af344a8025f95a4c1c897ab64a.txt
#  extracting: train/labels/2_1605_jpg.rf.473505430e76b0577eb48a063f3fc67c.txt
#  extracting: train/labels/2_1606_jpg.rf.83d0a12ca841a213af37d3316cff4a06.txt
#  extracting: train/labels/2_1608_jpg.rf.d2eff559084a819c3f67d98ce56ec399.txt
#  extracting: train/labels/2_1609_jpg.rf.b390eb7d32491898e2595ab7b528fd4e.txt
#  extracting: train/labels/2_160_jpg.rf.0c8aaf31794a599ba0516814b7760ddb.txt
#  extracting: train/labels/2_1611_jpg.rf.68e0b23a7314fe5d3ac65e43d3c8e459.txt
#  extracting: train/labels/2_1612_jpg.rf.0c03c5aa91e43b0eee3d76aa501fc7dc.txt
#  extracting: train/labels/2_1613_jpg.rf.22c9c3135de737de3055401a9ca0a474.txt
#  extracting: train/labels/2_1614_jpg.rf.8bcd76ccf5c41d6a06b576dad5c71090.txt
#  extracting: train/labels/2_1617_jpg.rf.c637b64be272e3993f0c66e2e182dcce.txt
#  extracting: train/labels/2_1618_jpg.rf.48acc0d91c9241d87fbee5df23ac0f0c.txt
#  extracting: train/labels/2_1619_jpg.rf.57f75dd553bcf390a5ce743fce851b96.txt
#  extracting: train/labels/2_161_jpg.rf.da0542a1a8fcb1ecb041b13c6122a24c.txt
#  extracting: train/labels/2_1623_jpg.rf.f789a4be8cf0c9858c70e1b66e8cd106.txt
#  extracting: train/labels/2_1624_jpg.rf.5dc4b89b3124a183664a322e09ac320e.txt
#  extracting: train/labels/2_1788_jpg.rf.4617174321c24e256060932b3c35d74d.txt
#  extracting: train/labels/2_1789_jpg.rf.0ae24f936b185aa2a7aa416d04786112.txt
#  extracting: train/labels/2_178_jpg.rf.6fb220d8e863ac1a6f1c511ad41c1f3f.txt
#  extracting: train/labels/2_1790_jpg.rf.bd20b90247c4b205d0d56033d54bebb5.txt
#  extracting: train/labels/2_1791_jpg.rf.897220fa1d21c79f1f904489b5237c6a.txt
#  extracting: train/labels/2_1792_jpg.rf.bbf686e08dbafb5cb332742711613448.txt
#  extracting: train/labels/2_1793_jpg.rf.8783cec36c84bce56359cc52a5293cd2.txt
#  extracting: train/labels/2_1794_jpg.rf.44446a322df94ade9aefd27ef22240ed.txt
#  extracting: train/labels/2_1795_jpg.rf.3e57ca645c10b32ef6dfe16f22f717b6.txt
#  extracting: train/labels/2_1796_jpg.rf.03340e93ce11666546a217fbe8671494.txt
#  extracting: train/labels/2_1797_jpg.rf.2d5e6a4b04aefdb29115dcb802121590.txt
#  extracting: train/labels/2_1798_jpg.rf.2283cfbd16fb38d3c138a5c38fe12f66.txt
#  extracting: train/labels/2_1799_jpg.rf.b0980a5bd5d7cd19e83835924cb8a8c4.txt
#  extracting: train/labels/2_179_jpg.rf.7fe1f03acf702f7857881714781fd270.txt
#  extracting: train/labels/2_17_jpg.rf.f0c53de4c93e3f5baee31a9bf5bef195.txt
#  extracting: train/labels/2_1800_jpg.rf.ffaef8f5ae751d036534404821d44934.txt
#  extracting: train/labels/2_1802_jpg.rf.a9a947b5c6286eaef9fad91aa934c1a3.txt
#  extracting: train/labels/2_1803_jpg.rf.ec014bd4615cf858e4ca26fd6c7409f1.txt
#  extracting: train/labels/2_1804_jpg.rf.cdeb464601e59863f032341bb63135e9.txt
#  extracting: train/labels/2_1805_jpg.rf.16b5d42a0457ba120c0e025e7c7799ba.txt
#  extracting: train/labels/2_1808_jpg.rf.630b947f8b0591a9e273154ccef9f23e.txt
#  extracting: train/labels/2_180_jpg.rf.c6cd6d8b2101085b85cc58b0b36144a8.txt
#  extracting: train/labels/2_1810_jpg.rf.30e59d796dcfbf850df3b5a10d68dc7b.txt
#  extracting: train/labels/2_1811_jpg.rf.0cca54366bef050660ed5800ae6de2de.txt
#  extracting: train/labels/2_1814_jpg.rf.91ce724e3b7cc5f6f84eb15d64e1ff48.txt
#  extracting: train/labels/2_1815_jpg.rf.aaf441cd89dcb100ba1d1a46d52d5c3c.txt
#  extracting: train/labels/2_1816_jpg.rf.96a8d9d9c5bd398009a7d7fa5d44ca0e.txt
#  extracting: train/labels/2_1817_jpg.rf.528768887cd61d8145a5700cfd9e602e.txt
#  extracting: train/labels/2_1819_jpg.rf.34fb07cb2c00de83d4cef0c054fe149b.txt
#  extracting: train/labels/2_181_jpg.rf.6476937ff117c1f7b392b319e71f55e1.txt
#  extracting: train/labels/2_1820_jpg.rf.e35508ddc142c962ad7aeff953e2dd42.txt
#  extracting: train/labels/2_1821_jpg.rf.e705a4849c57e7f603cc602804775168.txt
#  extracting: train/labels/2_1824_jpg.rf.8a13c42140b2b2751408f77544860a17.txt
#  extracting: train/labels/2_2035_jpg.rf.c214783fb13b5794d2130c8115b1e006.txt
#  extracting: train/labels/2_2036_jpg.rf.515df780fda2226ce2f2ecaa27bfe20a.txt
#  extracting: train/labels/2_2037_jpg.rf.f8b25b92cc5ccfbb797e92b713285091.txt
#  extracting: train/labels/2_2038_jpg.rf.b8d1479896cb76b46c1e077dd0481fb7.txt
#  extracting: train/labels/2_2039_jpg.rf.c29b84f60c7147d59e62656dad9069e7.txt
#  extracting: train/labels/2_203_jpg.rf.8ecd91c95281168fcbc3b4e14653c796.txt
#  extracting: train/labels/2_2040_jpg.rf.2f783d4d8372ea5c8e4b3ec69e89fe99.txt
#  extracting: train/labels/2_2041_jpg.rf.053d1d5ceeab773c3278618a75f3cf4d.txt
#  extracting: train/labels/2_2042_jpg.rf.2c8836c858f8fd1e7cabaffe6e9441f7.txt
# ...
#  extracting: valid/labels/2_4419_jpg.rf.170984c8c33c5ca7ef085fb4c10e3cb8.txt
#  extracting: valid/labels/2_4421_jpg.rf.cfdab5cc0ebd6940c67408dffa5716c7.txt
#  extracting: valid/labels/2_4422_jpg.rf.713469c5c76c575f4f946e2a81f8b1b1.txt
#  extracting: valid/labels/2_4432_jpg.rf.e4bdde4642c3aa8e1e7ab1a29beb8643.txt
#  extracting: valid/labels/2_4435_jpg.rf.68723021e0e8df45b1ee7337584d1af2.txt
#  extracting: valid/labels/2_4444_jpg.rf.aee2d07771084c7d24d4cc354182f827.txt
#  extracting: valid/labels/2_4445_jpg.rf.8322512746d80c3229c5ce9d43cd93e2.txt
#  extracting: valid/labels/2_4452_jpg.rf.b81539bcfc3f232b21e61fd935a793c0.txt
#  extracting: valid/labels/2_445_jpg.rf.3c34d9ffd1ff8200f5852806dff85195.txt
#  extracting: valid/labels/2_4460_jpg.rf.46c6fb56c8250d6e5c71a191d01ed37c.txt
#  extracting: valid/labels/2_4467_jpg.rf.e9b1dcd4b10380ce52c4b2d3125b8b4f.txt
#  extracting: valid/labels/2_4471_jpg.rf.189f7b615877224a9f2e1ef95d67739b.txt
#  extracting: valid/labels/2_447_jpg.rf.83d6f2b03696180a69f60eaa91fe7432.txt
#  extracting: valid/labels/2_4483_jpg.rf.4e702205b4e2b30c9ab5f02cb6e1879b.txt
#  extracting: valid/labels/2_4484_jpg.rf.bafe3c2d6481cf60bc5bcf542dd093ce.txt
#  extracting: valid/labels/2_4487_jpg.rf.759412a0dcb365a5666e4aaffd4ad974.txt
#  extracting: valid/labels/2_4493_jpg.rf.86626abe1aeb0c7e77051fd94a3c6134.txt
#  extracting: valid/labels/2_449_jpg.rf.805630924862638f5b675472ea798ed7.txt
#  extracting: valid/labels/2_4503_jpg.rf.4c1e50e4a516c4ba49f0f12948b15c4c.txt
#  extracting: valid/labels/2_4507_jpg.rf.55ab7817a56c34cbcc8b676623980065.txt
#  extracting: valid/labels/2_450_jpg.rf.9de31771bff49479a0bf6c2c5fd8d7a9.txt
#  extracting: valid/labels/2_4515_jpg.rf.133d8b706b50294094361de28b7343dc.txt
#  extracting: valid/labels/2_4656_jpg.rf.ca973a898097d43671e5727d676448a4.txt
#  extracting: valid/labels/2_465_jpg.rf.33a2777f3617bce3974d594ecc2dca36.txt
#  extracting: valid/labels/2_4660_jpg.rf.3b5f6d55d4f619dc9fa24cd0bb1c379b.txt
#  extracting: valid/labels/2_4663_jpg.rf.6dc215708445aca7d65f2eb2d9714cad.txt
#  extracting: valid/labels/2_4666_jpg.rf.3ce553597d11a3805ece3f2864afc6eb.txt
#  extracting: valid/labels/2_4670_jpg.rf.b9b61c3cd85386b7a5c5485538ddc0b9.txt
#  extracting: valid/labels/2_4672_jpg.rf.7526619217e24da0272c9abe3888c40a.txt
#  extracting: valid/labels/2_4673_jpg.rf.e08b7f762b0f43f47a4c993959579817.txt
#  extracting: valid/labels/2_4676_jpg.rf.a9309596fdf22fd975c45e41bd553004.txt
#  extracting: valid/labels/2_4677_jpg.rf.0b420516ef9a9cb38673c451766b4893.txt
#  extracting: valid/labels/2_467_jpg.rf.d4f801780301dc9b7e6387c71c17c5f4.txt
#  extracting: valid/labels/2_4683_jpg.rf.1d87872410c6c1fadbfd5a72d6ac7124.txt
#  extracting: valid/labels/2_4685_jpg.rf.855cf2a7da24530490282a251f73de59.txt
#  extracting: valid/labels/2_4688_jpg.rf.e5a2b48ff54fc1ab9fa502375b4f790f.txt
#  extracting: valid/labels/2_4698_jpg.rf.3a51f42ee673e4dbe536d906213c262f.txt
#  extracting: valid/labels/2_4707_jpg.rf.ad9e0e6e3e205544a9a3ba6932d254e5.txt
#  extracting: valid/labels/2_4716_jpg.rf.591c3fdb7d57a0367d617eb18e22d2cb.txt
#  extracting: valid/labels/2_4723_jpg.rf.e9e0a507dda71cabb36c074e9b9b9a07.txt
#  extracting: valid/labels/2_4724_jpg.rf.61536e0d70c584982607e1bee67b01c9.txt
#  extracting: valid/labels/2_479_jpg.rf.cbbad36f89c032bcdbff1fe3a635a2d1.txt
#  extracting: valid/labels/2_483_jpg.rf.07e6da5ceaa6ea4c5306e70ba2187d30.txt
#  extracting: valid/labels/2_486_jpg.rf.408168cbef8e17fa5c5f113b82d51033.txt
#  extracting: valid/labels/2_488_jpg.rf.9ade9faa79128dfe0dc32f5f3cfce508.txt
#  extracting: valid/labels/2_4_jpg.rf.9890ea9675c81f3a5a9071d15ef0ca91.txt
#  extracting: valid/labels/2_502_jpg.rf.278855afa17e3be2322456c58f531cf2.txt
#  extracting: valid/labels/2_512_jpg.rf.54dfe787e405928afafdb1202bfd2877.txt
#  extracting: valid/labels/2_521_jpg.rf.3e16ead903b9700bd3ea465fcd8bcc1b.txt
#  extracting: valid/labels/2_527_jpg.rf.d7760334239cdc1661b1fbfdcc67c7dc.txt
#  extracting: valid/labels/2_52_jpg.rf.98d098f23c217c8e0efdb60683635bec.txt
#  extracting: valid/labels/2_531_jpg.rf.b9c8966080d9f2ce59bd4070bb3c5a5a.txt
#  extracting: valid/labels/2_536_jpg.rf.d2dc348569353f8e500330d9b985abcf.txt
#  extracting: valid/labels/2_539_jpg.rf.aea37267fa1db82e0eac8f8149ae4b0b.txt
#  extracting: valid/labels/2_540_jpg.rf.36fe462065f6d90071654cdf5127c1cd.txt
#  extracting: valid/labels/2_542_jpg.rf.7ec1c5ed856fcbe64e01a4d9692c8169.txt
#  extracting: valid/labels/2_543_jpg.rf.9bd677547c3383736be068dfa2a6c5ae.txt
#  extracting: valid/labels/2_544_jpg.rf.32075826ad3e3223441baa1c17d2c8c5.txt
#  extracting: valid/labels/2_546_jpg.rf.d65e75ea9dfd28f54de1af9333f2c18e.txt
#  extracting: valid/labels/2_552_jpg.rf.257a17eb078bb4e8eb91aee411d35680.txt
#  extracting: valid/labels/2_556_jpg.rf.f5b29f7ff8d8e23d783b12ae01b54040.txt
#  extracting: valid/labels/2_563_jpg.rf.4d17c298a6f8b71f4c90d9f0a000cdd9.txt
#  extracting: valid/labels/2_56_jpg.rf.926b55d70e23236ac6f92e81517f1d87.txt
#  extracting: valid/labels/2_571_jpg.rf.5e7604785f732119426b0ecf74157ad1.txt
#  extracting: valid/labels/2_575_jpg.rf.557ad0a019287484f601d7a05d3eb26b.txt
#  extracting: valid/labels/2_577_jpg.rf.f08e585a7ad61f5f7a21b4e6dd77e1be.txt
#  extracting: valid/labels/2_578_jpg.rf.4b01b6a3f44e5aa18510e427c044222a.txt
#  extracting: valid/labels/2_582_jpg.rf.eee1589678c2b52ef2a78634716c17ab.txt
#  extracting: valid/labels/2_584_jpg.rf.f49517fc447b514fdade6bb0938da55c.txt
#  extracting: valid/labels/2_588_jpg.rf.3edb53809ee915469bba8996a07ba853.txt
#  extracting: valid/labels/2_590_jpg.rf.2e3d30f67bca8399972beadf2ee199e3.txt
#  extracting: valid/labels/2_591_jpg.rf.659b50ecbbba229d5d9c802e5109dfd2.txt
#  extracting: valid/labels/2_593_jpg.rf.fd00791963022331f8b5d11f2faed3d7.txt
#  extracting: valid/labels/2_601_jpg.rf.bd6e1c79959cb0d4e37ee38eb39bfc59.txt
#  extracting: valid/labels/2_602_jpg.rf.f613a0b1b3ed016cd1988879d7053dae.txt
#  extracting: valid/labels/2_606_jpg.rf.c78d1c779109efd8b19539cd37be3874.txt
#  extracting: valid/labels/2_608_jpg.rf.1b79bcb1cefbf484716c95bb921c9221.txt
#  extracting: valid/labels/2_609_jpg.rf.d4e3f9ee43cdef23afbc39359c3dc8ee.txt
#  extracting: valid/labels/2_618_jpg.rf.118795a78e635a6e923f3f1c1f8612b6.txt
#  extracting: valid/labels/2_620_jpg.rf.e934b0a580ab62e715a39dbabd89e460.txt
#  extracting: valid/labels/2_624_jpg.rf.613082f155c6dd032371b2693c1f41cc.txt
#  extracting: valid/labels/2_626_jpg.rf.01a2d0f291b60e428145c9ef3bc78aac.txt
#  extracting: valid/labels/2_631_jpg.rf.3bd2219099ab1e7983619aba387b19df.txt
#  extracting: valid/labels/2_633_jpg.rf.4c7aef9bedd2d1040fe4ccd14374c324.txt
#  extracting: valid/labels/2_636_jpg.rf.e1304df9ecf4001e8084360e05e7cf9c.txt
#  extracting: valid/labels/2_637_jpg.rf.bc7e063b305461ddd856d5f5c010aa84.txt
#  extracting: valid/labels/2_640_jpg.rf.66c39a07133cfedf8221783b4ab88987.txt
#  extracting: valid/labels/2_642_jpg.rf.0001d2e98d7ed8917a4787220f0bdea1.txt
#  extracting: valid/labels/2_643_jpg.rf.8ae037d20ec38703d03b471d9e907ce3.txt
#  extracting: valid/labels/2_645_jpg.rf.37a40a984ddb64e13b192b2d2c8847fd.txt
#  extracting: valid/labels/2_650_jpg.rf.f1959175d4f4bd5c8c4973f78d512b42.txt
#  extracting: valid/labels/2_651_jpg.rf.7c2422d6d10a848214b72d34e9bb61ad.txt
#  extracting: valid/labels/2_661_jpg.rf.63b9b366afac14a155ce36076fabad21.txt
#  extracting: valid/labels/2_670_jpg.rf.d80dc350aecbac32bc1f4280ae140ffa.txt
#  extracting: valid/labels/2_681_jpg.rf.a61ad51cbdbce32388d4c6b730640c52.txt
#  extracting: valid/labels/2_684_jpg.rf.06b7de33c930f3fb6a144f308e415d38.txt
#  extracting: valid/labels/2_685_jpg.rf.6f5b836b1cd5beb40077073d07d1abc6.txt
#  extracting: valid/labels/2_689_jpg.rf.549169a38760e2f8d727336fbfdc6229.txt
#  extracting: valid/labels/2_68_jpg.rf.ba49b5464b3190d17e7b40a7ec7c9c62.txt
#  extracting: valid/labels/2_691_jpg.rf.ba82419f42adc3b3df51a97bf5f16ed1.txt
#  extracting: valid/labels/2_695_jpg.rf.9608b738ba58a8a0556192c571e868ca.txt
#  extracting: valid/labels/2_705_jpg.rf.7d0c05cae1c8f9fcc576189863243bdd.txt
#  extracting: valid/labels/2_707_jpg.rf.360f253221e413f53c6522ceda033e67.txt
#  extracting: valid/labels/2_70_jpg.rf.6bb066236fc0149130ff1f865ffd7ed6.txt
#  extracting: valid/labels/2_713_jpg.rf.b603d36c93f8eca5516bb74f5bd38e7c.txt
#  extracting: valid/labels/2_714_jpg.rf.659aa016a07d72b3fcc37d519dd2d551.txt
#  extracting: valid/labels/2_719_jpg.rf.df51e69b423550db90b257ab0f485f5b.txt
#  extracting: valid/labels/2_723_jpg.rf.e5f7019e0ebc3617c614d2d45bc15d50.txt
#  extracting: valid/labels/2_749_jpg.rf.a45c286141cd9d9ba05e0b4dd0f5e5eb.txt
#  extracting: valid/labels/2_751_jpg.rf.18621cbf18853f2e4ea82cd929413fb0.txt
#  extracting: valid/labels/2_755_jpg.rf.5cacb2b1e6da179b8c79ae1cd7ae7ce9.txt
#  extracting: valid/labels/2_761_jpg.rf.23e2dd57067cecc9bca128aacb311b24.txt
#  extracting: valid/labels/2_769_jpg.rf.e1d0dd6b9855900054c8183e6f26041a.txt
#  extracting: valid/labels/2_770_jpg.rf.54926ad04fe3b3069d7d08670ba55d8c.txt
#  extracting: valid/labels/2_771_jpg.rf.2df26d2733e5926d36018e68517f18f8.txt
#  extracting: valid/labels/2_774_jpg.rf.4d92eca39594d6ef63de60d057d8a665.txt
#  extracting: valid/labels/2_77_jpg.rf.f46b62eaae1132e76e6147822dca2f64.txt
#  extracting: valid/labels/2_789_jpg.rf.a9681c66d80383dfb14898708de2aa4c.txt
#  extracting: valid/labels/2_796_jpg.rf.27cc96ce040a1490cdcb8bfe3044f086.txt
#  extracting: valid/labels/2_804_jpg.rf.6f61af730f5a30b329bbbe12cf53f582.txt
#  extracting: valid/labels/2_805_jpg.rf.af86fbda641d3b654ed49a939230c68b.txt
#  extracting: valid/labels/2_808_jpg.rf.daf74394b8cc231608a9841150483f75.txt
#  extracting: valid/labels/2_814_jpg.rf.601ee6d225068d2fb1febbb031a3707d.txt
#  extracting: valid/labels/2_819_jpg.rf.fccb1cad382e860b1e0eb9ed10402b6a.txt
#  extracting: valid/labels/2_81_jpg.rf.965834ed52e0a5b6e24cc29eb6a67f2a.txt
#  extracting: valid/labels/2_822_jpg.rf.bd0c71e2f5326d1bb66b8c2c8d267b2b.txt
#  extracting: valid/labels/2_826_jpg.rf.4c3ad900ad984132c5a49d5fe2bf5f0d.txt
#  extracting: valid/labels/2_827_jpg.rf.dddeefa126042b9d6ea7b46d1ef6bdf9.txt
#  extracting: valid/labels/2_833_jpg.rf.016f7ef0cda6c263913a6bc8190d4e40.txt
#  extracting: valid/labels/2_840_jpg.rf.25bc8cf33fd8dc8f2a9fe3078e5013ca.txt
#  extracting: valid/labels/2_848_jpg.rf.2f8c90fd55bed054425cddfc8533df19.txt
#  extracting: valid/labels/2_85_jpg.rf.86e87a26173fcb2dbcc2d4dd79da3af9.txt
#  extracting: valid/labels/2_860_jpg.rf.86446328d3918ec115c3261b6d05be4f.txt
#  extracting: valid/labels/2_862_jpg.rf.4d0db66f288456181362920486171087.txt
#  extracting: valid/labels/2_866_jpg.rf.45ef878db5720902425777969fec9087.txt
#  extracting: valid/labels/2_867_jpg.rf.7219b946116f1b8c02a8a5a43ce1a72d.txt
#  extracting: valid/labels/2_875_jpg.rf.a8d3babf190486d7406271a0072c3a23.txt
#  extracting: valid/labels/2_883_jpg.rf.fc7cd3a222ec7d30661e19088d2fa3a5.txt
#  extracting: valid/labels/2_885_jpg.rf.1f40c8c7c966860d2473733c6b0d6287.txt
#  extracting: valid/labels/2_886_jpg.rf.2513e659b6a1e120671a138377e457fa.txt
#  extracting: valid/labels/2_887_jpg.rf.edbd7bebb01ba46fdc76ac6185d12c18.txt
#  extracting: valid/labels/2_888_jpg.rf.9c49d29d8d4403e19108977818ad5461.txt
#  extracting: valid/labels/2_892_jpg.rf.05b38ade96daa326c15a5c82266cb184.txt
#  extracting: valid/labels/2_896_jpg.rf.aff2cd7d63382645a117fa2145b46ad8.txt
#  extracting: valid/labels/2_897_jpg.rf.4590cda06e2859a5fc8ae7d1469dddf6.txt
#  extracting: valid/labels/2_911_jpg.rf.cf6eaa6d946bd4d7a1976aa53f437efa.txt
#  extracting: valid/labels/2_912_jpg.rf.3ed8f94a8f6b7b06f5fa8dfa38ffc75f.txt
#  extracting: valid/labels/2_917_jpg.rf.47c253855b493088931e7c1aa5d6683a.txt
#  extracting: valid/labels/2_918_jpg.rf.70052c8339b784fd457e136f40edcef9.txt
#  extracting: valid/labels/2_919_jpg.rf.9ea41c0ec4b34fa8b5a0dbae6e269b3f.txt
#  extracting: valid/labels/2_921_jpg.rf.bb867dddeabc219e9625e887958c1c6d.txt
#  extracting: valid/labels/2_923_jpg.rf.c7c01230d787e390d272b57b5bf91a72.txt
#  extracting: valid/labels/2_925_jpg.rf.5c622a16fadd3e2be7d11d02efae099f.txt
#  extracting: valid/labels/2_930_jpg.rf.447e107282040131dfe47c8feaa6e358.txt
#  extracting: valid/labels/2_931_jpg.rf.c7bcb78ee5aa7a9eb5b916b57158af08.txt
#  extracting: valid/labels/2_937_jpg.rf.4881ac429e477596dd5bf8dda191b1ad.txt
#  extracting: valid/labels/2_938_jpg.rf.5feaaa7d7b7e7c5321fabbbdf88bd338.txt
#  extracting: valid/labels/2_939_jpg.rf.da20e3936e4020caec6fce76cf4dc77e.txt
#  extracting: valid/labels/2_941_jpg.rf.3a3509439989d676c370700e82bfef10.txt
#  extracting: valid/labels/2_945_jpg.rf.cbdd749af66f4642b2312602dc91ba1c.txt
#  extracting: valid/labels/2_946_jpg.rf.b8754e8966846a219e5266d23aeb2423.txt
#  extracting: valid/labels/2_947_jpg.rf.255141d272a7e740cbca574cf45b1807.txt
#  extracting: valid/labels/2_94_jpg.rf.a60fae74dfe983eab39260bc141e56c4.txt
#  extracting: valid/labels/2_954_jpg.rf.0c3d9cd5d63bb9adb5482a6738b0e886.txt
#  extracting: valid/labels/2_955_jpg.rf.6ad411ac198530b689a64fb8a0d94ac4.txt
#  extracting: valid/labels/2_960_jpg.rf.279f624217dd6122b2b3a3a71001b53a.txt
#  extracting: valid/labels/2_969_jpg.rf.5bbf3e37e4ad4d0dbc8445fd3ef24a9b.txt
#  extracting: valid/labels/2_976_jpg.rf.838af9017b1547cdab759758f98f18c4.txt
#  extracting: valid/labels/2_978_jpg.rf.6491dc4af4b6b57a8a0a703df7faf945.txt
#  extracting: valid/labels/2_98_jpg.rf.74b89aea325c3c5c58f675f115883e7c.txt
#  extracting: valid/labels/2_997_jpg.rf.260dc6d2003e374e03586422e20f2824.txt
#  extracting: valid/labels/2_998_jpg.rf.5f6d3311facdc267512a3e8519b3202e.txt

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 1
# names: ['text']

# %%
# define number of classes based on YAML
import yaml
with open("data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
#this is the model configuration we will use for our tutorial 
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
####Optional Temp Fix###
#if during training, you get a missing labels error, here is a fix for the data loader

# %%
# temp fix for image_weights=opt.image_weights error, see: https://github.com/ultralytics/yolov5/issues/1550
# %%writefile /content/yolov5/utils/train.py
import argparse
import logging
import math
import os
import random
import time
from pathlib import Path
from warnings import warn

import numpy as np
import torch.distributed as dist
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.utils.data
import yaml
from torch.cuda import amp
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm

import test  # import test.py to get mAP after each epoch
from models.yolo import Model
from utils.autoanchor import check_anchors
from utils.datasets import create_dataloader
from utils.general import labels_to_class_weights, increment_path, labels_to_image_weights, init_seeds, \
    fitness, strip_optimizer, get_latest_run, check_dataset, check_file, check_git_status, check_img_size, \
    print_mutation, set_logging
from utils.google_utils import attempt_download
from utils.loss import compute_loss
from utils.plots import plot_images, plot_labels, plot_results, plot_evolution
from utils.torch_utils import ModelEMA, select_device, intersect_dicts, torch_distributed_zero_first

logger = logging.getLogger(__name__)

try:
    import wandb
except ImportError:
    wandb = None
    logger.info("Install Weights & Biases for experiment logging via 'pip install wandb' (recommended)")


def train(hyp, opt, device, tb_writer=None, wandb=None):
    logger.info(f'Hyperparameters {hyp}')
    save_dir, epochs, batch_size, total_batch_size, weights, rank = \
        Path(opt.save_dir), opt.epochs, opt.batch_size, opt.total_batch_size, opt.weights, opt.global_rank

    # Directories
    wdir = save_dir / 'weights'
    wdir.mkdir(parents=True, exist_ok=True)  # make dir
    last = wdir / 'last.pt'
    best = wdir / 'best.pt'
    results_file = save_dir / 'results.txt'

    # Save run settings
    with open(save_dir / 'hyp.yaml', 'w') as f:
        yaml.dump(hyp, f, sort_keys=False)
    with open(save_dir / 'opt.yaml', 'w') as f:
        yaml.dump(vars(opt), f, sort_keys=False)

    # Configure
    plots = not opt.evolve  # create plots
    cuda = device.type != 'cpu'
    init_seeds(2 + rank)
    with open(opt.data) as f:
        data_dict = yaml.load(f, Loader=yaml.FullLoader)  # data dict
    with torch_distributed_zero_first(rank):
        check_dataset(data_dict)  # check
    train_path = data_dict['train']
    test_path = data_dict['val']
    nc, names = (1, ['item']) if opt.single_cls else (int(data_dict['nc']), data_dict['names'])  # number classes, names
    assert len(names) == nc, '%g names found for nc=%g dataset in %s' % (len(names), nc, opt.data)  # check

    # Model
    pretrained = weights.endswith('.pt')
    if pretrained:
        with torch_distributed_zero_first(rank):
            attempt_download(weights)  # download if not found locally
        ckpt = torch.load(weights, map_location=device)  # load checkpoint
        if hyp.get('anchors'):
            ckpt['model'].yaml['anchors'] = round(hyp['anchors'])  # force autoanchor
        model = Model(opt.cfg or ckpt['model'].yaml, ch=3, nc=nc).to(device)  # create
        exclude = ['anchor'] if opt.cfg or hyp.get('anchors') else []  # exclude keys
        state_dict = ckpt['model'].float().state_dict()  # to FP32
        state_dict = intersect_dicts(state_dict, model.state_dict(), exclude=exclude)  # intersect
        model.load_state_dict(state_dict, strict=False)  # load
        logger.info('Transferred %g/%g items from %s' % (len(state_dict), len(model.state_dict()), weights))  # report
    else:
        model = Model(opt.cfg, ch=3, nc=nc).to(device)  # create

    # Freeze
    freeze = []  # parameter names to freeze (full or partial)
    for k, v in model.named_parameters():
        v.requires_grad = True  # train all layers
        if any(x in k for x in freeze):
            print('freezing %s' % k)
            v.requires_grad = False

    # Optimizer
    nbs = 64  # nominal batch size
    accumulate = max(round(nbs / total_batch_size), 1)  # accumulate loss before optimizing
    hyp['weight_decay'] *= total_batch_size * accumulate / nbs  # scale weight_decay

    pg0, pg1, pg2 = [], [], []  # optimizer parameter groups
    for k, v in model.named_modules():
        if hasattr(v, 'bias') and isinstance(v.bias, nn.Parameter):
            pg2.append(v.bias)  # biases
        if isinstance(v, nn.BatchNorm2d):
            pg0.append(v.weight)  # no decay
        elif hasattr(v, 'weight') and isinstance(v.weight, nn.Parameter):
            pg1.append(v.weight)  # apply decay

    if opt.adam:
        optimizer = optim.Adam(pg0, lr=hyp['lr0'], betas=(hyp['momentum'], 0.999))  # adjust beta1 to momentum
    else:
        optimizer = optim.SGD(pg0, lr=hyp['lr0'], momentum=hyp['momentum'], nesterov=True)

    optimizer.add_param_group({'params': pg1, 'weight_decay': hyp['weight_decay']})  # add pg1 with weight_decay
    optimizer.add_param_group({'params': pg2})  # add pg2 (biases)
    logger.info('Optimizer groups: %g .bias, %g conv.weight, %g other' % (len(pg2), len(pg1), len(pg0)))
    del pg0, pg1, pg2

    # Scheduler https://arxiv.org/pdf/1812.01187.pdf
    # https://pytorch.org/docs/stable/_modules/torch/optim/lr_scheduler.html#OneCycleLR
    lf = lambda x: ((1 + math.cos(x * math.pi / epochs)) / 2) * (1 - hyp['lrf']) + hyp['lrf']  # cosine
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lf)
    # plot_lr_scheduler(optimizer, scheduler, epochs)

    # Logging
    if wandb and wandb.run is None:
        opt.hyp = hyp  # add hyperparameters
        wandb_run = wandb.init(config=opt, resume="allow",
                               project='YOLOv5' if opt.project == 'runs/train' else Path(opt.project).stem,
                               name=save_dir.stem,
                               id=ckpt.get('wandb_id') if 'ckpt' in locals() else None)

    # Resume
    start_epoch, best_fitness = 0, 0.0
    if pretrained:
        # Optimizer
        if ckpt['optimizer'] is not None:
            optimizer.load_state_dict(ckpt['optimizer'])
            best_fitness = ckpt['best_fitness']

        # Results
        if ckpt.get('training_results') is not None:
            with open(results_file, 'w') as file:
                file.write(ckpt['training_results'])  # write results.txt

        # Epochs
        start_epoch = ckpt['epoch'] + 1
        if opt.resume:
            assert start_epoch > 0, '%s training to %g epochs is finished, nothing to resume.' % (weights, epochs)
        if epochs < start_epoch:
            logger.info('%s has been trained for %g epochs. Fine-tuning for %g additional epochs.' %
                        (weights, ckpt['epoch'], epochs))
            epochs += ckpt['epoch']  # finetune additional epochs

        del ckpt, state_dict

    # Image sizes
    gs = int(max(model.stride))  # grid size (max stride)
    imgsz, imgsz_test = [check_img_size(x, gs) for x in opt.img_size]  # verify imgsz are gs-multiples

    # DP mode
    if cuda and rank == -1 and torch.cuda.device_count() > 1:
        model = torch.nn.DataParallel(model)

    # SyncBatchNorm
    if opt.sync_bn and cuda and rank != -1:
        model = torch.nn.SyncBatchNorm.convert_sync_batchnorm(model).to(device)
        logger.info('Using SyncBatchNorm()')

    # EMA
    ema = ModelEMA(model) if rank in [-1, 0] else None

    # DDP mode
    if cuda and rank != -1:
        model = DDP(model, device_ids=[opt.local_rank], output_device=opt.local_rank)

    # Trainloader
    dataloader, dataset = create_dataloader(train_path, imgsz, batch_size, gs, opt,
                                            hyp=hyp, augment=True, cache=opt.cache_images, rect=opt.rect, rank=rank,
                                            world_size=opt.world_size, workers=opt.workers)
    mlc = np.concatenate(dataset.labels, 0)[:, 0].max()  # max label class
    nb = len(dataloader)  # number of batches
    assert mlc < nc, 'Label class %g exceeds nc=%g in %s. Possible class labels are 0-%g' % (mlc, nc, opt.data, nc - 1)

    # Process 0
    if rank in [-1, 0]:
        ema.updates = start_epoch * nb // accumulate  # set EMA updates
        testloader = create_dataloader(test_path, imgsz_test, total_batch_size, gs, opt,
                                       hyp=hyp, cache=opt.cache_images and not opt.notest, rect=True,
                                       rank=-1, world_size=opt.world_size, workers=opt.workers)[0]  # testloader

        if not opt.resume:
            labels = np.concatenate(dataset.labels, 0)
            c = torch.tensor(labels[:, 0])  # classes
            # cf = torch.bincount(c.long(), minlength=nc) + 1.  # frequency
            # model._initialize_biases(cf.to(device))
            if plots:
                plot_labels(labels, save_dir=save_dir)
                if tb_writer:
                    tb_writer.add_histogram('classes', c, 0)
                if wandb:
                    wandb.log({"Labels": [wandb.Image(str(x), caption=x.name) for x in save_dir.glob('*labels*.png')]})

            # Anchors
            if not opt.noautoanchor:
                check_anchors(dataset, model=model, thr=hyp['anchor_t'], imgsz=imgsz)

    # Model parameters
    hyp['cls'] *= nc / 80.  # scale coco-tuned hyp['cls'] to current dataset
    model.nc = nc  # attach number of classes to model
    model.hyp = hyp  # attach hyperparameters to model
    model.gr = 1.0  # iou loss ratio (obj_loss = 1.0 or iou)
    model.class_weights = labels_to_class_weights(dataset.labels, nc).to(device)  # attach class weights
    model.names = names

    # Start training
    t0 = time.time()
    nw = max(round(hyp['warmup_epochs'] * nb), 1000)  # number of warmup iterations, max(3 epochs, 1k iterations)
    # nw = min(nw, (epochs - start_epoch) / 2 * nb)  # limit warmup to < 1/2 of training
    maps = np.zeros(nc)  # mAP per class
    results = (0, 0, 0, 0, 0, 0, 0)  # P, R, mAP@.5, mAP@.5-.95, val_loss(box, obj, cls)
    scheduler.last_epoch = start_epoch - 1  # do not move
    scaler = amp.GradScaler(enabled=cuda)
    logger.info('Image sizes %g train, %g test\n'
                'Using %g dataloader workers\nLogging results to %s\n'
                'Starting training for %g epochs...' % (imgsz, imgsz_test, dataloader.num_workers, save_dir, epochs))
    for epoch in range(start_epoch, epochs):  # epoch ------------------------------------------------------------------
        model.train()

        # Update image weights (optional)
        if opt.image_weights:
            # Generate indices
            if rank in [-1, 0]:
                cw = model.class_weights.cpu().numpy() * (1 - maps) ** 2  # class weights
                iw = labels_to_image_weights(dataset.labels, nc=nc, class_weights=cw)  # image weights
                dataset.indices = random.choices(range(dataset.n), weights=iw, k=dataset.n)  # rand weighted idx
            # Broadcast if DDP
            if rank != -1:
                indices = (torch.tensor(dataset.indices) if rank == 0 else torch.zeros(dataset.n)).int()
                dist.broadcast(indices, 0)
                if rank != 0:
                    dataset.indices = indices.cpu().numpy()

        # Update mosaic border
        # b = int(random.uniform(0.25 * imgsz, 0.75 * imgsz + gs) // gs * gs)
        # dataset.mosaic_border = [b - imgsz, -b]  # height, width borders

        mloss = torch.zeros(4, device=device)  # mean losses
        if rank != -1:
            dataloader.sampler.set_epoch(epoch)
        pbar = enumerate(dataloader)
        logger.info(('\n' + '%10s' * 8) % ('Epoch', 'gpu_mem', 'box', 'obj', 'cls', 'total', 'targets', 'img_size'))
        if rank in [-1, 0]:
            pbar = tqdm(pbar, total=nb)  # progress bar
        optimizer.zero_grad()
        for i, (imgs, targets, paths, _) in pbar:  # batch -------------------------------------------------------------
            ni = i + nb * epoch  # number integrated batches (since train start)
            imgs = imgs.to(device, non_blocking=True).float() / 255.0  # uint8 to float32, 0-255 to 0.0-1.0

            # Warmup
            if ni <= nw:
                xi = [0, nw]  # x interp
                # model.gr = np.interp(ni, xi, [0.0, 1.0])  # iou loss ratio (obj_loss = 1.0 or iou)
                accumulate = max(1, np.interp(ni, xi, [1, nbs / total_batch_size]).round())
                for j, x in enumerate(optimizer.param_groups):
                    # bias lr falls from 0.1 to lr0, all other lrs rise from 0.0 to lr0
                    x['lr'] = np.interp(ni, xi, [hyp['warmup_bias_lr'] if j == 2 else 0.0, x['initial_lr'] * lf(epoch)])
                    if 'momentum' in x:
                        x['momentum'] = np.interp(ni, xi, [hyp['warmup_momentum'], hyp['momentum']])

            # Multi-scale
            if opt.multi_scale:
                sz = random.randrange(imgsz * 0.5, imgsz * 1.5 + gs) // gs * gs  # size
                sf = sz / max(imgs.shape[2:])  # scale factor
                if sf != 1:
                    ns = [math.ceil(x * sf / gs) * gs for x in imgs.shape[2:]]  # new shape (stretched to gs-multiple)
                    imgs = F.interpolate(imgs, size=ns, mode='bilinear', align_corners=False)

            # Forward
            with amp.autocast(enabled=cuda):
                pred = model(imgs)  # forward
                loss, loss_items = compute_loss(pred, targets.to(device), model)  # loss scaled by batch_size
                if rank != -1:
                    loss *= opt.world_size  # gradient averaged between devices in DDP mode

            # Backward
            scaler.scale(loss).backward()

            # Optimize
            if ni % accumulate == 0:
                scaler.step(optimizer)  # optimizer.step
                scaler.update()
                optimizer.zero_grad()
                if ema:
                    ema.update(model)

            # Print
            if rank in [-1, 0]:
                mloss = (mloss * i + loss_items) / (i + 1)  # update mean losses
                mem = '%.3gG' % (torch.cuda.memory_reserved() / 1E9 if torch.cuda.is_available() else 0)  # (GB)
                s = ('%10s' * 2 + '%10.4g' * 6) % (
                    '%g/%g' % (epoch, epochs - 1), mem, *mloss, targets.shape[0], imgs.shape[-1])
                pbar.set_description(s)

                # Plot
                if plots and ni < 3:
                    f = save_dir / f'train_batch{ni}.jpg'  # filename
                    plot_images(images=imgs, targets=targets, paths=paths, fname=f)
                    # if tb_writer:
                    #     tb_writer.add_image(f, result, dataformats='HWC', global_step=epoch)
                    #     tb_writer.add_graph(model, imgs)  # add model to tensorboard
                elif plots and ni == 3 and wandb:
                    wandb.log({"Mosaics": [wandb.Image(str(x), caption=x.name) for x in save_dir.glob('train*.jpg')]})

            # end batch ------------------------------------------------------------------------------------------------
        # end epoch ----------------------------------------------------------------------------------------------------

        # Scheduler
        lr = [x['lr'] for x in optimizer.param_groups]  # for tensorboard
        scheduler.step()

        # DDP process 0 or single-GPU
        if rank in [-1, 0]:
            # mAP
            if ema:
                ema.update_attr(model, include=['yaml', 'nc', 'hyp', 'gr', 'names', 'stride'])
            final_epoch = epoch + 1 == epochs
            if not opt.notest or final_epoch:  # Calculate mAP
                results, maps, times = test.test(opt.data,
                                                 batch_size=total_batch_size,
                                                 imgsz=imgsz_test,
                                                 model=ema.ema,
                                                 single_cls=opt.single_cls,
                                                 dataloader=testloader,
                                                 save_dir=save_dir,
                                                 plots=plots and final_epoch,
                                                 log_imgs=opt.log_imgs if wandb else 0)

            # Write
            with open(results_file, 'a') as f:
                f.write(s + '%10.4g' * 7 % results + '\n')  # P, R, mAP@.5, mAP@.5-.95, val_loss(box, obj, cls)
            if len(opt.name) and opt.bucket:
                os.system('gsutil cp %s gs://%s/results/results%s.txt' % (results_file, opt.bucket, opt.name))

            # Log
            tags = ['train/box_loss', 'train/obj_loss', 'train/cls_loss',  # train loss
                    'metrics/precision', 'metrics/recall', 'metrics/mAP_0.5', 'metrics/mAP_0.5:0.95',
                    'val/box_loss', 'val/obj_loss', 'val/cls_loss',  # val loss
                    'x/lr0', 'x/lr1', 'x/lr2']  # params
            for x, tag in zip(list(mloss[:-1]) + list(results) + lr, tags):
                if tb_writer:
                    tb_writer.add_scalar(tag, x, epoch)  # tensorboard
                if wandb:
                    wandb.log({tag: x})  # W&B

            # Update best mAP
            fi = fitness(np.array(results).reshape(1, -1))  # weighted combination of [P, R, mAP@.5, mAP@.5-.95]
            if fi > best_fitness:
                best_fitness = fi

            # Save model
            save = (not opt.nosave) or (final_epoch and not opt.evolve)
            if save:
                with open(results_file, 'r') as f:  # create checkpoint
                    ckpt = {'epoch': epoch,
                            'best_fitness': best_fitness,
                            'training_results': f.read(),
                            'model': ema.ema,
                            'optimizer': None if final_epoch else optimizer.state_dict(),
                            'wandb_id': wandb_run.id if wandb else None}

                # Save last, best and delete
                torch.save(ckpt, last)
                if best_fitness == fi:
                    torch.save(ckpt, best)
                del ckpt
        # end epoch ----------------------------------------------------------------------------------------------------
    # end training

    if rank in [-1, 0]:
        # Strip optimizers
        n = opt.name if opt.name.isnumeric() else ''
        fresults, flast, fbest = save_dir / f'results{n}.txt', wdir / f'last{n}.pt', wdir / f'best{n}.pt'
        for f1, f2 in zip([wdir / 'last.pt', wdir / 'best.pt', results_file], [flast, fbest, fresults]):
            if f1.exists():
                os.rename(f1, f2)  # rename
                if str(f2).endswith('.pt'):  # is *.pt
                    strip_optimizer(f2)  # strip optimizer
                    os.system('gsutil cp %s gs://%s/weights' % (f2, opt.bucket)) if opt.bucket else None  # upload
        # Finish
        if plots:
            plot_results(save_dir=save_dir)  # save as results.png
            if wandb:
                files = ['results.png', 'precision_recall_curve.png', 'confusion_matrix.png']
                wandb.log({"Results": [wandb.Image(str(save_dir / f), caption=f) for f in files
                                       if (save_dir / f).exists()]})
        logger.info('%g epochs completed in %.3f hours.\n' % (epoch - start_epoch + 1, (time.time() - t0) / 3600))
    else:
        dist.destroy_process_group()

    wandb.run.finish() if wandb and wandb.run else None
    torch.cuda.empty_cache()
    return results


if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--weights', type=str, default='yolov5s.pt', help='initial weights path')
    parser.add_argument('--cfg', type=str, default='', help='model.yaml path')
    parser.add_argument('--data', type=str, default='data/coco128.yaml', help='data.yaml path')
    parser.add_argument('--hyp', type=str, default='data/hyp.scratch.yaml', help='hyperparameters path')
    parser.add_argument('--epochs', type=int, default=300)
    parser.add_argument('--batch-size', type=int, default=16, help='total batch size for all GPUs')
    parser.add_argument('--img-size', nargs='+', type=int, default=[640, 640], help='[train, test] image sizes')
    parser.add_argument('--rect', action='store_true', help='rectangular training')
    parser.add_argument('--resume', nargs='?', const=True, default=False, help='resume most recent training')
    parser.add_argument('--nosave', action='store_true', help='only save final checkpoint')
    parser.add_argument('--notest', action='store_true', help='only test final epoch')
    parser.add_argument('--noautoanchor', action='store_true', help='disable autoanchor check')
    parser.add_argument('--evolve', action='store_true', help='evolve hyperparameters')
    parser.add_argument('--bucket', type=str, default='', help='gsutil bucket')
    parser.add_argument('--cache-images', action='store_true', help='cache images for faster training')
    parser.add_argument('--image-weights', action='store_true', help='use weighted image selection for training')
    parser.add_argument('--device', default='', help='cuda device, i.e. 0 or 0,1,2,3 or cpu')
    parser.add_argument('--multi-scale', action='store_true', help='vary img-size +/- 50%%')
    parser.add_argument('--single-cls', action='store_true', help='train as single-class dataset')
    parser.add_argument('--adam', action='store_true', help='use torch.optim.Adam() optimizer')
    parser.add_argument('--sync-bn', action='store_true', help='use SyncBatchNorm, only available in DDP mode')
    parser.add_argument('--local_rank', type=int, default=-1, help='DDP parameter, do not modify')
    parser.add_argument('--log-imgs', type=int, default=16, help='number of images for W&B logging, max 100')
    parser.add_argument('--workers', type=int, default=8, help='maximum number of dataloader workers')
    parser.add_argument('--project', default='runs/train', help='save to project/name')
    parser.add_argument('--name', default='exp', help='save to project/name')
    parser.add_argument('--exist-ok', action='store_true', help='existing project/name ok, do not increment')
    opt = parser.parse_args()

    # Set DDP variables
    opt.total_batch_size = opt.batch_size
    opt.world_size = int(os.environ['WORLD_SIZE']) if 'WORLD_SIZE' in os.environ else 1
    opt.global_rank = int(os.environ['RANK']) if 'RANK' in os.environ else -1
    set_logging(opt.global_rank)
    if opt.global_rank in [-1, 0]:
        check_git_status()

    # Resume
    if opt.resume:  # resume an interrupted run
        ckpt = opt.resume if isinstance(opt.resume, str) else get_latest_run()  # specified or most recent path
        assert os.path.isfile(ckpt), 'ERROR: --resume checkpoint does not exist'
        with open(Path(ckpt).parent.parent / 'opt.yaml') as f:
            opt = argparse.Namespace(**yaml.load(f, Loader=yaml.FullLoader))  # replace
        opt.cfg, opt.weights, opt.resume = '', ckpt, True
        logger.info('Resuming training from %s' % ckpt)
    else:
        # opt.hyp = opt.hyp or ('hyp.finetune.yaml' if opt.weights else 'hyp.scratch.yaml')
        opt.data, opt.cfg, opt.hyp = check_file(opt.data), check_file(opt.cfg), check_file(opt.hyp)  # check files
        assert len(opt.cfg) or len(opt.weights), 'either --cfg or --weights must be specified'
        opt.img_size.extend([opt.img_size[-1]] * (2 - len(opt.img_size)))  # extend to 2 sizes (train, test)
        opt.name = 'evolve' if opt.evolve else opt.name
        opt.save_dir = increment_path(Path(opt.project) / opt.name, exist_ok=opt.exist_ok | opt.evolve)  # increment run

    # DDP mode
    device = select_device(opt.device, batch_size=opt.batch_size)
    if opt.local_rank != -1:
        assert torch.cuda.device_count() > opt.local_rank
        torch.cuda.set_device(opt.local_rank)
        device = torch.device('cuda', opt.local_rank)
        dist.init_process_group(backend='nccl', init_method='env://')  # distributed backend
        assert opt.batch_size % opt.world_size == 0, '--batch-size must be multiple of CUDA device count'
        opt.batch_size = opt.total_batch_size // opt.world_size

    # Hyperparameters
    with open(opt.hyp) as f:
        hyp = yaml.load(f, Loader=yaml.FullLoader)  # load hyps
        if 'box' not in hyp:
            warn('Compatibility: %s missing "box" which was renamed from "giou" in %s' %
                 (opt.hyp, 'https://github.com/ultralytics/yolov5/pull/1120'))
            hyp['box'] = hyp.pop('giou')

    # Train
    logger.info(opt)
    if not opt.evolve:
        tb_writer = None  # init loggers
        if opt.global_rank in [-1, 0]:
            logger.info(f'Start Tensorboard with "tensorboard --logdir {opt.project}", view at http://localhost:6006/')
            tb_writer = SummaryWriter(opt.save_dir)  # Tensorboard
        train(hyp, opt, device, tb_writer, wandb)

    # Evolve hyperparameters (optional)
    else:
        # Hyperparameter evolution metadata (mutation scale 0-1, lower_limit, upper_limit)
        meta = {'lr0': (1, 1e-5, 1e-1),  # initial learning rate (SGD=1E-2, Adam=1E-3)
                'lrf': (1, 0.01, 1.0),  # final OneCycleLR learning rate (lr0 * lrf)
                'momentum': (0.3, 0.6, 0.98),  # SGD momentum/Adam beta1
                'weight_decay': (1, 0.0, 0.001),  # optimizer weight decay
                'warmup_epochs': (1, 0.0, 5.0),  # warmup epochs (fractions ok)
                'warmup_momentum': (1, 0.0, 0.95),  # warmup initial momentum
                'warmup_bias_lr': (1, 0.0, 0.2),  # warmup initial bias lr
                'box': (1, 0.02, 0.2),  # box loss gain
                'cls': (1, 0.2, 4.0),  # cls loss gain
                'cls_pw': (1, 0.5, 2.0),  # cls BCELoss positive_weight
                'obj': (1, 0.2, 4.0),  # obj loss gain (scale with pixels)
                'obj_pw': (1, 0.5, 2.0),  # obj BCELoss positive_weight
                'iou_t': (0, 0.1, 0.7),  # IoU training threshold
                'anchor_t': (1, 2.0, 8.0),  # anchor-multiple threshold
                'anchors': (2, 2.0, 10.0),  # anchors per output grid (0 to ignore)
                'fl_gamma': (0, 0.0, 2.0),  # focal loss gamma (efficientDet default gamma=1.5)
                'hsv_h': (1, 0.0, 0.1),  # image HSV-Hue augmentation (fraction)
                'hsv_s': (1, 0.0, 0.9),  # image HSV-Saturation augmentation (fraction)
                'hsv_v': (1, 0.0, 0.9),  # image HSV-Value augmentation (fraction)
                'degrees': (1, 0.0, 45.0),  # image rotation (+/- deg)
                'translate': (1, 0.0, 0.9),  # image translation (+/- fraction)
                'scale': (1, 0.0, 0.9),  # image scale (+/- gain)
                'shear': (1, 0.0, 10.0),  # image shear (+/- deg)
                'perspective': (0, 0.0, 0.001),  # image perspective (+/- fraction), range 0-0.001
                'flipud': (1, 0.0, 1.0),  # image flip up-down (probability)
                'fliplr': (0, 0.0, 1.0),  # image flip left-right (probability)
                'mosaic': (1, 0.0, 1.0),  # image mixup (probability)
                'mixup': (1, 0.0, 1.0)}  # image mixup (probability)

        assert opt.local_rank == -1, 'DDP mode not implemented for --evolve'
        opt.notest, opt.nosave = True, True  # only test/save final epoch
        # ei = [isinstance(x, (int, float)) for x in hyp.values()]  # evolvable indices
        yaml_file = Path(opt.save_dir) / 'hyp_evolved.yaml'  # save best result here
        if opt.bucket:
            os.system('gsutil cp gs://%s/evolve.txt .' % opt.bucket)  # download evolve.txt if exists

        for _ in range(300):  # generations to evolve
            if Path('evolve.txt').exists():  # if evolve.txt exists: select best hyps and mutate
                # Select parent(s)
                parent = 'single'  # parent selection method: 'single' or 'weighted'
                x = np.loadtxt('evolve.txt', ndmin=2)
                n = min(5, len(x))  # number of previous results to consider
                x = x[np.argsort(-fitness(x))][:n]  # top n mutations
                w = fitness(x) - fitness(x).min()  # weights
                if parent == 'single' or len(x) == 1:
                    # x = x[random.randint(0, n - 1)]  # random selection
                    x = x[random.choices(range(n), weights=w)[0]]  # weighted selection
                elif parent == 'weighted':
                    x = (x * w.reshape(n, 1)).sum(0) / w.sum()  # weighted combination

                # Mutate
                mp, s = 0.8, 0.2  # mutation probability, sigma
                npr = np.random
                npr.seed(int(time.time()))
                g = np.array([x[0] for x in meta.values()])  # gains 0-1
                ng = len(meta)
                v = np.ones(ng)
                while all(v == 1):  # mutate until a change occurs (prevent duplicates)
                    v = (g * (npr.random(ng) < mp) * npr.randn(ng) * npr.random() * s + 1).clip(0.3, 3.0)
                for i, k in enumerate(hyp.keys()):  # plt.hist(v.ravel(), 300)
                    hyp[k] = float(x[i + 7] * v[i])  # mutate

            # Constrain to limits
            for k, v in meta.items():
                hyp[k] = max(hyp[k], v[1])  # lower limit
                hyp[k] = min(hyp[k], v[2])  # upper limit
                hyp[k] = round(hyp[k], 5)  # significant digits

            # Train mutation
            results = train(hyp.copy(), opt, device, wandb=wandb)

            # Write mutation results
            print_mutation(hyp.copy(), results, yaml_file, opt.bucket)

        # Plot results
        plot_evolution(yaml_file)
        print(f'Hyperparameter evolution complete. Best results saved as: {yaml_file}\n'
              f'Command to train a new model with these hyperparameters: $ python train.py --hyp {yaml_file}')
# Out:
# Writing /content/yolov5/utils/train.py

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 100 --data '../data.yaml' --cfg ./models/custom_yolov5s.yaml --weights /content/drive/MyDrive/best.pt --name yolov5s_results  --cache
# Out:
# /content/yolov5
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15109MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='./models/custom_yolov5s.yaml', data='../data.yaml', device='', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], local_rank=-1, log_imgs=16, multi_scale=False, name='yolov5s_results', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/yolov5s_results', single_cls=False, sync_bn=False, total_batch_size=16, weights='/content/drive/MyDrive/best.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2021-02-24 14:34:24.618645: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Hyperparameters {'lr0': 0.01, 'lrf': 0.2, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'box': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0}
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7255094 parameters, 7255094 gradients
#
# Transferred 368/370 items from /content/drive/MyDrive/best.pt
# Optimizer groups: 62 .bias, 70 conv.weight, 59 other
# Scanning '../train/labels' for images and labels... 3313 found, 0 missing, 0 empty, 0 corrupted: 100% 3313/3313 [00:00<00:00, 3407.84it/s]
# New cache created: ../train/labels.cache
# Scanning '../train/labels.cache' for images and labels... 3313 found, 0 missing, 0 empty, 0 corrupted: 100% 3313/3313 [00:00<00:00, 34652691.15it/s]
# Caching images (1.7GB): 100% 3313/3313 [00:06<00:00, 508.77it/s]
# Scanning '../valid/labels' for images and labels... 946 found, 0 missing, 0 empty, 0 corrupted: 100% 946/946 [00:00<00:00, 1634.15it/s]
# New cache created: ../valid/labels.cache
# Scanning '../valid/labels.cache' for images and labels... 946 found, 0 missing, 0 empty, 0 corrupted: 100% 946/946 [00:00<00:00, 7645109.03it/s]
# Caching images (0.5GB): 100% 946/946 [00:01<00:00, 517.40it/s]
# NumExpr defaulting to 2 threads.
#
# Analyzing anchors... anchors/target = 5.71, Best Possible Recall (BPR) = 1.0000
# Image sizes 416 train, 416 test
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       0/99     1.82G   0.04019   0.07455         0    0.1147         9       416: 100% 208/208 [00:34<00:00,  6.11it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:06<00:00,  9.97it/s]
#                  all         946    4.58e+03       0.638       0.891       0.895       0.552
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       1/99     1.86G   0.03887   0.06839         0    0.1073        13       416: 100% 208/208 [00:30<00:00,  6.89it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:05<00:00, 10.45it/s]
#                  all         946    4.58e+03       0.728       0.892       0.907       0.567
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       2/99     1.86G   0.03866   0.06821         0    0.1069         8       416: 100% 208/208 [00:29<00:00,  6.97it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:05<00:00, 10.33it/s]
#                  all         946    4.58e+03       0.774       0.903        0.92        0.58
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       3/99     1.86G   0.03874   0.06752         0    0.1063         6       416: 100% 208/208 [00:29<00:00,  7.10it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:05<00:00, 10.01it/s]
#                  all         946    4.58e+03       0.662       0.901       0.908       0.553
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       4/99     1.86G   0.04043   0.06676         0    0.1072         5       416: 100% 208/208 [00:28<00:00,  7.18it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:06<00:00,  9.84it/s]
#                  all         946    4.58e+03       0.771       0.886       0.906       0.534
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       5/99     1.86G   0.04045    0.0683         0    0.1088         8       416: 100% 208/208 [00:28<00:00,  7.21it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:06<00:00,  9.94it/s]
#                  all         946    4.58e+03       0.663       0.914        0.92       0.548
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       6/99     1.86G   0.03979   0.06749         0    0.1073         5       416: 100% 208/208 [00:28<00:00,  7.22it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:05<00:00, 10.26it/s]
#                  all         946    4.58e+03       0.743        0.89       0.905       0.539
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       7/99     1.86G   0.03905   0.06441         0    0.1035         1       416: 100% 208/208 [00:28<00:00,  7.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:06<00:00,  9
/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:05<00:00, 10.45it/s]
#                  all         946    4.58e+03       0.831       0.963       0.971        0.69
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      98/99     1.86G   0.02815   0.04809         0   0.07624         8       416: 100% 208/208 [00:29<00:00,  7.13it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:06<00:00,  9.57it/s]
#                  all         946    4.58e+03       0.829       0.961       0.971        0.69
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      99/99     1.86G   0.02811   0.04899         0   0.07709         3       416: 100% 208/208 [00:28<00:00,  7.20it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 60/60 [00:08<00:00,  6.94it/s]
#                  all         946    4.58e+03       0.834       0.964       0.973        0.69
# Optimizer stripped from runs/train/yolov5s_results/weights/last.pt, 14.7MB
# Optimizer stripped from runs/train/yolov5s_results/weights/best.pt, 14.7MB
# 100 epochs completed in 0.971 hours.
#
# CPU times: user 21.6 s, sys: 3.79 s, total: 25.4 s
# Wall time: 58min 53s

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`. (If given no name, it defaults to `results.txt`.) The results file is plotted as a png after training completes.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source ../test/images
# Out:
# /content/yolov5
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../test/images', update=False, view_img=False, weights=['runs/train/yolov5s_results/weights/best.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15109MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# image 1/473 /content/test/images/2_1028_jpg.rf.ae8ee7dbf3386ee3015a735853c86cb7.jpg: 416x416 6 texts, Done. (0.011s)
# image 2/473 /content/test/images/2_1030_jpg.rf.83fca0e160b1f76789fc17438bacb565.jpg: 416x416 9 texts, Done. (0.011s)
# image 3/473 /content/test/images/2_1041_jpg.rf.f330e32de88baad264789bdec4c8a9e8.jpg: 416x416 2 texts, Done. (0.009s)
# image 4/473 /content/test/images/2_1042_jpg.rf.4b39b291d2c10ab2e11c4fb423bcf5e0.jpg: 416x416 5 texts, Done. (0.009s)
# image 5/473 /content/test/images/2_1044_jpg.rf.bfdc4457d7a92b2c701e02c069180f2a.jpg: 416x416 7 texts, Done. (0.009s)
# image 456/473 /content/test/images/2_847_jpg.rf.2280f431ba32c3c4b34a52897992922d.jpg: 416x416 5 texts, Done. (0.011s)
# image 457/473 /content/test/images/2_854_jpg.rf.966d708970a98fa3ae9d5d5fd4ec7596.jpg: 416x416 8 texts, Done. (0.011s)
# image 458/473 /content/test/images/2_859_jpg.rf.93c467606ad314ee300d5f419c6041c6.jpg: 416x416 2 texts, Done. (0.011s)
# image 459/473 /content/test/images/2_86_jpg.rf.5a1cdca23a68b65986dca7394e644afa.jpg: 416x416 2 texts, Done. (0.011s)
# image 460/473 /content/test/images/2_878_jpg.rf.8f6923d2522d9603422cf628c733d130.jpg: 416x416 5 texts, Done. (0.010s)
# image 461/473 /content/test/images/2_895_jpg.rf.4fc53f89ffc4fa636dd56cd777748b26.jpg: 416x416 5 texts, Done. (0.010s)
# image 462/473 /content/test/images/2_8_jpg.rf.6f84afed9caa1fd64481a7232982f1d0.jpg: 416x416 2 texts, Done. (0.010s)
# image 463/473 /content/test/images/2_901_jpg.rf.a9fad5fcb0e24d6ba3c7f2b31be26fda.jpg: 416x416 4 texts, Done. (0.010s)
# image 464/473 /content/test/images/2_915_jpg.rf.a6d5ed1b08c59c675036eebb59d132ce.jpg: 416x416 8 texts, Done. (0.010s)
# image 465/473 /content/test/images/2_926_jpg.rf.a06b54844848daeaa3b8565be9ddd08d.jpg: 416x416 9 texts, Done. (0.010s)
# image 466/473 /content/test/images/2_942_jpg.rf.44428d872ee98aea6aa5c396bd736b1b.jpg: 416x416 6 texts, Done. (0.008s)
# image 467/473 /content/test/images/2_956_jpg.rf.1e2fc7958ef66a7467c3409c3b85b599.jpg: 416x416 7 texts, Done. (0.008s)
# image 468/473 /content/test/images/2_959_jpg.rf.055c65def15639adc572db4434e4f82c.jpg: 416x416 7 texts, Done. (0.009s)
# image 469/473 /content/test/images/2_961_jpg.rf.8f26c6b9cefd1940ea95c1fc2def9335.jpg: 416x416 6 texts, Done. (0.008s)
# image 470/473 /content/test/images/2_974_jpg.rf.7dffdb3b40316e35def3e9108f85d703.jpg: 416x416 14 texts, Done. (0.008s)
# image 471/473 /content/test/images/2_985_jpg.rf.ad65179c020d3d9981de45c6fcb3a01f.jpg: 416x416 9 texts, Done. (0.011s)
# image 472/473 /content/test/images/2_992_jpg.rf.4b1461c7b4141ce04b5ad5a646613630.jpg: 416x416 9 texts, Done. (0.009s)
# image 473/473 /content/test/images/2_999_jpg.rf.9ff0b0ad48bc9ecf50e7d0bf9de0cd2a.jpg: 416x416 6 texts, Done. (0.008s)
# Results saved to runs/detect/exp
# Done. (8.247s)

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Export Trained Weights for Future Inference
#
# Now that you have trained your custom detector, you can export the trained weights you have made here for inference on your device elsewhere

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/MyDrive/Colab_Notebooks
